# %% [markdown]
# <a href="https://colab.research.google.com/github/Vayansh/Yolo_training/blob/master/Project-3_Construction_site_safety_detection/Construction_site_safety.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/Construction_Site_Safety.v30-raw-images_latestversion.yolov8.zip'

# %%
# !pip install ultralytics==8.0.26
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.6/271.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.4 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8m.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# 2023-07-30 08:44:15.231880: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-30 08:44:16.131405: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 70.3MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 108.9ms
# Speed: 0.7ms pre-process, 108.9ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# # Custom Training

# %%
import cv2 as cv

# %%
img = cv.imread('/content/train/images/-1670-_png_jpg.rf.401e319f51f626c5e05ec0692c49b6c4.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
# !yolo task=detect  mode=train model=yolov8m.pt  data= ../content/datasets/construction_safety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model= /content/runs/detect/train5/weights/best.pt conf=0.25 source='/content/datasets/construction_safety/test/images/000005_jpg.rf.c613c066b79795d219855aca269760e6.jpg'
# Out:
# 2023-08-04 10:56:38.955670: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-04 10:56:40.373771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25854235 parameters, 0 gradients, 78.8 GFLOPs
#
# image 1/1 /content/datasets/construction_safety/test/images/000005_jpg.rf.c613c066b79795d219855aca269760e6.jpg: 448x640 1 Hardhat, 2 NO-Masks, 1 NO-Safety Vest, 2 Persons, 70.5ms
# Speed: 0.6ms pre-process, 70.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
